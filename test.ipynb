# %%
# !git clone https://github.com/docker/welcome-to-docker
# Out:
# Cloning into 'welcome-to-docker'...
# remote: Enumerating objects: 94, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 94 (delta 26), reused 21 (delta 21), pack-reused 61
# Receiving objects: 100% (94/94), 312.69 KiB | 5.58 MiB/s, done.
# Resolving deltas: 100% (43/43), done.

# %%
# !docker pull nvcr.io/nvidia/pytorch:22.08-py3
# Out:
# 22.08-py3: Pulling from nvidia/pytorch
#
# a280e3e9: Pulling fs layer
# 885b51b2: Pulling fs layer
# 67522494: Pulling fs layer
# 8572b951: Pulling fs layer
# 763bd858: Pulling fs layer
# 66aec5f7: Pulling fs layer
# 09ab7b90: Pulling fs layer
# 868109e0: Pulling fs layer
# 763bd858: Waiting fs layer
# 66aec5f7: Waiting fs layer
# 98d9ba99: Pulling fs layer
# 09ab7b90: Waiting fs layer
# 868109e0: Waiting fs layer
# b4b68cdb: Waiting fs layer
# 28d8596e: Pulling fs layer
# 28d8596e: Waiting fs layer
# 0de9c106: Pulling fs layer
# 1ec4cb4a: Pulling fs layer
# aa3d7978: Pulling fs layer
# 196c3878: Pulling fs layer
# 51507080: Pulling fs layer
# 793f9582: Pulling fs layer
# 447a3a0d: Pulling fs layer
# 9732bdc5: Pulling fs layer
# f447d721: Pulling fs layer
# 1f651789: Pulling fs layer
# 55682da3: Pulling fs layer
# bbd267c: Waiting fs layer
# 9732bdc5: Waiting fs layer
# f447d721: Waiting fs layer
# 1f651789: Waiting fs layer
# 2e0224c7: Waiting fs layer
# 5f6469a1: Waiting fs layer
# e3d160d8: Pulling fs layer
# 33aeb9aa: Waiting fs layer
# e31e9b51: Pulling fs layer
# 49c3f393: Waiting fs layer
# 9fd29b9a: Pulling fs layer
# efbe5d54: Waiting fs layer
# 9fd29b9a: Waiting fs layer
# 3f739e83: Pulling fs layer
# 142774ed: Waiting fs layer
# 6a684e7f: Pulling fs layer
# 37dca25f: Pulling fs layer
# 6a684e7f: Waiting fs layer
# a53ade1f: Pulling fs layer
# 4b68cdb: Downloading  5.314MB/902.3MBDownloading  1.983MB/27.19MBDownloading  22.92MB/97.74MBDownloading  30.94MB/90.22MBDownloading  45.83MB/97.74MBDownloading  85.84MB/90.22MBDownloading  36.68MB/40.82MBDownloading  2.153MB/1.105GBDownloading   41.6MB/1.105GBDownloading  55.97MB/1.105GBDownloading  66.63MB/1.105GBDownloading  94.88MB/1.105GBDownloading  108.2MB/1.105GBDownloading  116.2MB/1.105GBDownloading   92.7MB/2.117GBDownloading  11.52MB/29.7MB

# %%
# !docker run -dit --gpus all --shm-size=8G --name baseline_sa nvcr.io/nvidia/pytorch:23.05-py3
